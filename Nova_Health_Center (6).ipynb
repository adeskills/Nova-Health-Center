# %%
## Step1 : Import all the necessary EDA libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt  #(visualization library (Static))
import seaborn as sns            # visualizationlibrary (dynamic)

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('/content/diabetes_clinical_records.csv')

# %%
df.head()
# Out:
#   PatientID  Age  Gender   BMI  BloodPressure  Glucose  Insulin  ExerciseDays  \
# 0  PT_00001   56  Female  19.2            111      114        5             1
# 1  PT_00002   69  Female  30.7            148      180       14             7
# 2  PT_00003   46  Female  20.7            125       71        7             4
# 3  PT_00004   32    Male  31.0            128      145        3             4
# 4  PT_00005   60    Male  24.6            140       94        2             6
#
#   SmokingStatus  FamilyHistory  DiabetesRiskScore  DiabetesDiagnosis
# 0         Never              1          30.429557                  1
# 1         Never              0          21.174730                  0
# 2       Current              1          31.004533                  1
# 3         Never              1          35.756383                  1
# 4        Former              0          23.552142                  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   PatientID          10000 non-null  object
#  1   Age                10000 non-null  int64
#  2   Gender             10000 non-null  object
#  3   BMI                10000 non-null  float64
#  4   BloodPressure      10000 non-null  int64
#  5   Glucose            10000 non-null  int64
#  6   Insulin            10000 non-null  int64
#  7   ExerciseDays       10000 non-null  int64
#  8   SmokingStatus      10000 non-null  object
#  9   FamilyHistory      10000 non-null  int64
#  10  DiabetesRiskScore  10000 non-null  float64
#  11  DiabetesDiagnosis  10000 non-null  int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
df.describe()
# Out:
#                 Age           BMI  BloodPressure       Glucose       Insulin  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean      48.798400     25.168800     119.490900    102.191000      9.851100
# std       17.903223      4.586149      15.200376     25.963234      9.419087
# min       18.000000     18.000000      70.000000     70.000000      2.000000
# 25%       34.000000     21.600000     109.000000     79.000000      2.000000
# 50%       49.000000     25.000000     119.000000    100.000000      7.000000
# 75%       64.000000     28.300000     130.000000    120.000000     14.000000
# max       79.000000     40.000000     179.000000    207.000000     50.000000
#
#        ExerciseDays  FamilyHistory  DiabetesRiskScore  DiabetesDiagnosis
# count  10000.000000   10000.000000       10000.000000       10000.000000
# mean       3.473400       0.300800          25.915353           0.536000
# ...

# %%
df.describe(include='object')
# Out:
#        PatientID  Gender SmokingStatus
# count      10000   10000         10000
# unique     10000       2             3
# top     PT_09984  Female         Never
# freq           1    5131          6035

# %%
# Handling missing values

# %%
df.isnull().sum()
# Out:
# PatientID            0
# Age                  0
# Gender               0
# BMI                  0
# BloodPressure        0
# Glucose              0
# Insulin              0
# ExerciseDays         0
# SmokingStatus        0
# FamilyHistory        0
# DiabetesRiskScore    0
# DiabetesDiagnosis    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Check for duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.tail(10)
# Out:
#      PatientID  Age  Gender   BMI  BloodPressure  Glucose  Insulin  \
# 9990  PT_09991   49    Male  19.4            101      106        2
# 9991  PT_09992   52  Female  20.1            112       70       14
# 9992  PT_09993   32  Female  27.8            135       70        2
# 9993  PT_09994   65    Male  22.9            107       70        9
# 9994  PT_09995   53  Female  26.1            142      139       17
# 9995  PT_09996   38  Female  27.3            130       70        3
# 9996  PT_09997   23    Male  33.0            116      184       16
# 9997  PT_09998   18    Male  26.0             91      142        2
# 9998  PT_09999   21    Male  22.3            135      127        2
# 9999  PT_10000   28  Female  24.6            129       70        5
#
#       ExerciseDays SmokingStatus  FamilyHistory  DiabetesRiskScore  \
# 9990             5         Never              1          27.422938
# 9991             2         Never              1          30.959990
# ...

# %%
#Generate the correlation of all features to the target(Diabetes diagnosis)

# %%
# Heatmap to visualize correlation


import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,3))
sns.heatmap(numerical_data.corr(),annot=True, fmt='.2f',cmap='Set2')
# Out:
# <Axes: >

# %%
# Data Preprocessing
# This is done to get the data ready for processing.

# Data Encoding:Converting categorical variables into numerical variables

# Data Scaling:Using certain statistical measures to normalise all numerical variables

# Encoding Techniques: Label encoding and One-Hot encoding

# Label encoding is used when there is a sense or order or hierarchy in your dataset.

# One-Hot encoding is used when there is no bit of hierarchy in your dataset.
# However,it encodes in binary format hence creating multiple other features to the dataset.

# Scaling: Using certain statistical measures to normalize all numerical variables for prediction.

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# Initialize label encoder

le = LabelEncoder()

# %%
df['Gender'] = le.fit_transform(df['Gender'])
df['SmokingStatus'] = le.fit_transform(df['SmokingStatus'])

# %%
df.head()
# Out:
#   PatientID  Age  Gender   BMI  BloodPressure  Glucose  Insulin  ExerciseDays  \
# 0  PT_00001   56       0  19.2            111      114        5             1
# 1  PT_00002   69       0  30.7            148      180       14             7
# 2  PT_00003   46       0  20.7            125       71        7             4
# 3  PT_00004   32       1  31.0            128      145        3             4
# 4  PT_00005   60       1  24.6            140       94        2             6
#
#    SmokingStatus  FamilyHistory  DiabetesRiskScore  DiabetesDiagnosis
# 0              2              1          30.429557                  1
# 1              2              0          21.174730                  0
# 2              0              1          31.004533                  1
# 3              2              1          35.756383                  1
# 4              1              0          23.552142                  0

# %%
# Split data into features and targets

X = df.drop('DiabetesDiagnosis', axis=1)
Y = df['DiabetesDiagnosis']

# %%
X.head()
# Out:
#   PatientID  Age  Gender   BMI  BloodPressure  Glucose  Insulin  ExerciseDays  \
# 0  PT_00001   56       0  19.2            111      114        5             1
# 1  PT_00002   69       0  30.7            148      180       14             7
# 2  PT_00003   46       0  20.7            125       71        7             4
# 3  PT_00004   32       1  31.0            128      145        3             4
# 4  PT_00005   60       1  24.6            140       94        2             6
#
#    SmokingStatus  FamilyHistory  DiabetesRiskScore
# 0              2              1          30.429557
# 1              2              0          21.174730
# 2              0              1          31.004533
# 3              2              1          35.756383
# 4              1              0          23.552142

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: DiabetesDiagnosis, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# Drop non numeric columns (like PatientID)

X = X.select_dtypes(include=['number'])

# Then scale only numeric features
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
display(X)
# Out:
# array([[ 0.4022717 , -0.9741344 , -1.30154927, ...,  0.74570685,
#          1.52462064,  0.49511427],
#        [ 1.12843423, -0.9741344 ,  1.20612674, ...,  0.74570685,
#         -0.65590087, -0.51994763],
#        [-0.15631486, -0.9741344 , -0.97446109, ..., -1.74454811,
#          1.52462064,  0.55817716],
#        ...,
#        [-1.72035724,  1.02655239,  0.18125046, ..., -0.49942063,
#         -0.65590087,  1.06837829],
#        [-1.55278127,  1.02655239, -0.62556704, ...,  0.74570685,
#         -0.65590087,  0.35659493],
#        [-1.16177068, -0.9741344 , -0.12403184, ...,  0.74570685,
#         -0.65590087, -1.95396147]])

# %%
# Univariate analysis

# %%
numerical_data = df.select_dtypes(exclude='object')

# %%
numerical_data.head()
# Out:
#    Age  Gender   BMI  BloodPressure  Glucose  Insulin  ExerciseDays  \
# 0   56       0  19.2            111      114        5             1
# 1   69       0  30.7            148      180       14             7
# 2   46       0  20.7            125       71        7             4
# 3   32       1  31.0            128      145        3             4
# 4   60       1  24.6            140       94        2             6
#
#    SmokingStatus  FamilyHistory  DiabetesRiskScore  DiabetesDiagnosis
# 0              2              1          30.429557                  1
# 1              2              0          21.174730                  0
# 2              0              1          31.004533                  1
# 3              2              1          35.756383                  1
# 4              1              0          23.552142                  0

# %%
categorical_data = df.select_dtypes(include='object')

# %%
categorical_data.head()
# Out:
#   PatientID
# 0  PT_00001
# 1  PT_00002
# 2  PT_00003
# 3  PT_00004
# 4  PT_00005

# %%
len(numerical_data.columns)
# Out:
# 11

# %%
len(categorical_data.columns)
# Out:
# 1

# %% [markdown]
# Train Test Split
#
# It means you are splitting your data into two parts, training data andb testing data.
#
# Usually done in 80% and 20% proportion.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
print(f'Original data; {df.shape}')
print(f'Full features; {X.shape}')
print(f'Full target; {Y.shape}')
print(f'Feature Training Data; {X_train.shape}')
print(f'Target Training Data; {Y_train.shape}')
print(f'Feature Testing Data; {X_test.shape}')
print(f'Target Testing Data; {Y_test.shape}')
# Out:
# Original data; (10000, 12)
# Full features; (10000, 10)
# Full target; (10000,)
# Feature Training Data; (8000, 10)
# Target Training Data; (8000,)
# Feature Testing Data; (2000, 10)
# Target Testing Data; (2000,)

# %%
# Train our models
# Classification models: We have

#1.logistic regression
#2.Random Forest Classifier
#3.XG Boost Classifier
#4. Support Vector Machine
#5.Naive Baye's Theorem

# Regression Models
# -Linear Regression
#  -Random Forest Regressor
# -XG Boost
# -Decision Tree

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

# %%
pip install xgboost

# %%
import numpy as np

# Drop column index 0 (for example)
X_train = np.delete(X_train, 0, axis=1)
X_test = np.delete(X_test, 0, axis=1)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
# Drop the string column(like PatientID)

X_train = X_train.drop(columns=['PatientID'])
X_test = X_test.drop(columns=['PatientID'])

# %%
X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

# Align columns to avoid shape mismatch
X_train, X_test = X_train.align(X_test, join='left', axis=1, fill_value=0)

# %%
# Safety check before training

print(X_train.select_dtypes(include=['object', 'string']).columns)

# %%
print(X_train.select_dtypes(include=['object', 'string']).columns)

# %%
# Define all models in a function

models ={
'Logistic Regression' : LogisticRegression(max_iter=1000),
'Random Forest'   : RandomForestClassifier(n_estimators=100),
'XGBoost' : XGBClassifier(use_label_encoder=False,eval_metric='logloss'),
'SVM'  : SVC(probability=True),
'Naive Bayes' : GaussianNB(),
'Decision Tree' : RandomForestClassifier(max_depth=3)
}

for name, model in models.items():
    model.fit(X_train,Y_train)
    train_score = model.score(X_train,Y_train)
    test_score = model.score(X_test,Y_test)
    print(f'{name} Train_Accuracy: {train_score: .2f}')
    print(f'{name} Test_Accuracy: {train_score: .2f}')
# Out:
# Logistic Regression Train_Accuracy:  1.00
# Logistic Regression Test_Accuracy:  1.00
# Random Forest Train_Accuracy:  1.00
# Random Forest Test_Accuracy:  1.00
# XGBoost Train_Accuracy:  1.00
# XGBoost Test_Accuracy:  1.00
# SVM Train_Accuracy:  0.99
# SVM Test_Accuracy:  0.99
# Naive Bayes Train_Accuracy:  0.94
# Naive Bayes Test_Accuracy:  0.94
# Decision Tree Train_Accuracy:  1.00
# Decision Tree Test_Accuracy:  1.00

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
for name, model in models.items():
    model.fit(X_train,Y_train)
    Y_pred = model.predict(X_test)
    acc = accuracy_score(Y_test,Y_pred)
    print(f'{name} Accuracy; {acc:.4f}')
    print(classification_report(Y_test,Y_pred))
    print(confusion_matrix(Y_test,Y_pred))
# Out:
# Logistic Regression Accuracy; 0.9955
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       922
#            1       1.00      0.99      1.00      1078
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000
#
# [[ 920    2]
#  [   7 1071]]
# Random Forest Accuracy; 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       922
#            1       1.00      1.00      1.00      1078
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000
#
# [[ 922    0]
#  [   0 1078]]
# XGBoost Accuracy; 0.9990
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       922
# ...

# %%
model_rf= RandomForestClassifier(n_estimators=100)

model_rf.fit(X_train,Y_train)
score = model_rf.score(X_test,Y_test)
print(f'Accuracy: {score:.2f}')
# Out:
# Accuracy: 1.00

# %%
rf_pred = model_rf.predict(X_test)
print("Classification report:", classification_report(Y_test,Y_pred))
# Out:
# Classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       922
#            1       1.00      1.00      1.00      1078
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000

# %% [markdown]
# Save the Model

# %%
import joblib
import pickle

joblib.dump(model_rf,'diabetes_model.pkl')
# Out:
# ['diabetes_model.pkl']

# %% [markdown]
# Prediction

# %%
# Load your saved model

rf_model = joblib.load('diabetes_model.pkl')

# Create a sample data
sample_input = {
    'Age': [67],
    'Gender':['Female'],
    'BMI' : [29.5],
    'BloodPressure': [130],
    'Glucose' : [149],
    'Insulin'  : [15],
    'SmokingStatus' : ['Former'],
    'FamilyHistory' : [1],
    'DiabetesRiskScore' : [35.355]
}

#Convert to data frame

input_df = pd.DataFrame(sample_input)

# Mapping Gender and SmokingStatus

input_df['Gender'] = input_df['Gender'].map({'Male':1, 'Female':0})
input_df['SmokingStatus']=input_df['SmokingStatus'].map({
       'Never':0,
       'Former':1,
       'Current':2
       })

# %%
input_df
# Out:
#    Age  Gender   BMI  BloodPressure  Glucose  Insulin  SmokingStatus  \
# 0   67       0  29.5            130      149       15              1
#
#    FamilyHistory  DiabetesRiskScore
# 0              1             35.355

# %%
prediction = rf_model.predict(input_df)
probability = rf_model.predict_proba(input_df)

# %%
# Show prediction result for the data supplied

print(f"Predicted Diabetes Status: {'Positive' if prediction[0] == 1 else 'Negative'}")
print(f'Probability: {probability[0][1]*100:.2f}% chance of diabetes')
# Out:
# Predicted Diabetes Status: Positive
# Probability: 98.00% chance of diabetes

# %%
df['DiabetesDiagnosis'].value_counts()
# Out:
# DiabetesDiagnosis
# 1    5360
# 0    4640
# Name: count, dtype: int64
